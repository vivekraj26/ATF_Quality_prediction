# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("movies.csv")
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df1 = pd.read_csv("tags.csv")

# %%
df1
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df1[df1["movieId"]==2571]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %%
rat = pd.read_csv("ratings.csv")
rat
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rat["userId"].nunique()
# Out:
# 610

# %%
rat["rating"].groupby(rat["movieId"]).sum().sort_values(ascending=False)
# Out:
# movieId
# 318       1404.0
# 356       1370.0
# 296       1288.5
# 2571      1165.5
# 593       1161.0
#            ...
# 160872       0.5
# 8236         0.5
# 57326        0.5
# 82684        0.5
# 138798       0.5
# Name: rating, Length: 9724, dtype: float64

# %%
df[df["title"]=="Fight Club (1999)"]
# Out:
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller

# %%
ff = rat[rat["movieId"]==2959]["rating"]

# %%
rat[rat["movieId"]==2959]["rating"].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.plot(ff,)

# %%
list_of_movies = list(rat["userId"].groupby(rat["movieId"]).count().sort_values(ascending=False)[rat["userId"].groupby(rat["movieId"]).count().sort_values(ascending=False)>50].index)

# %%
list_of_movies
# Out:
# [356,
#  318,
#  296,
#  593,
#  2571,
#  260,
#  480,
#  110,
#  589,
#  527,
#  2959,
#  1,
#  1196,
#  50,
#  2858,
#  47,
#  780,
#  150,
#  1198,
#  4993,
#  1210,
#  858,
#  457,
#  592,
#  5952,
#  2028,
#  7153,
#  588,
#  608,
#  2762,
#  380,
#  32,
#  364,
#  1270,
#  377,
#  3578,
#  4306,
#  1580,
#  590,
#  648,
#  344,
#  4226,
#  367,
#  58559,
#  6539,
#  1214,
#  595,
#  1036,
#  165,
#  500,
#  1265,
#  79132,
#  1197,
#  6377,
#  1704,
#  316,
#  2628,
#  1291,
#  1721,
#  153,
#  1136,
#  597,
#  293,
#  1193,
#  3793,
#  231,
#  4886,
#  10,
#  1089,
#  7361,
#  6874,
#  1240,
#  1221,
#  2329,
#  34,
#  1200,
#  1213,
#  1682,
#  8961,
#  541,
#  4995,
#  736,
#  5349,
#  1097,
#  2683,
#  733,
#  2716,
#  1206,
#  4973,
#  5445,
#  1073,
#  4963,
#  586,
#  33794,
#  1527,
#  208,
#  587,
#  5989,
#  1968,
#  185,
#  5418,
#  3147,
#  3996,
#  349,
#  2,
#  7438,
#  2918,
#  1258,
#  924,
#  4878,
#  253,
#  2115,
#  329,
#  1208,
#  4896,
#  48516,
#  539,
# ...

# %%
rat[rat["movieId"]==318]
# Out:
#        userId  movieId  rating   timestamp
# 232         2      318     3.0  1445714835
# 536         5      318     3.0   847434880
# 703         6      318     5.0   845553200
# 1051        8      318     5.0   839463489
# 1271       11      318     4.0   902155070
# ...       ...      ...     ...         ...
# 97424     606      318     3.5  1171927228
# 98498     607      318     5.0   963080679
# 98727     608      318     4.5  1147210910
# 99511     609      318     4.0   847220907
# 99554     610      318     3.0  1479541963
#
# [317 rows x 4 columns]

# %%
aaa = rat[rat["movieId"].isin(list_of_movies)]

# %%
aaa["rating"].groupby(aaa["movieId"]).mean().sort_values(ascending=False)
# Out:
# movieId
# 318     4.429022
# 858     4.289062
# 2959    4.272936
# 1276    4.271930
# 750     4.268041
#           ...
# 172     2.679245
# 173     2.669355
# 432     2.645455
# 435     2.420635
# 2701    2.207547
# Name: rating, Length: 436, dtype: float64

# %%
df[df["movieId"].isin([2710])]
# Out:
#       movieId                            title                 genres
# 2035     2710  Blair Witch Project, The (1999)  Drama|Horror|Thriller

# %%
aaa["rating"].groupby(aaa["movieId"]).mean().sort_values(ascending=False)[:5].index
# Out:
# Int64Index([318, 858, 2959, 1276, 750], dtype='int64', name='movieId')

# %%
rat["userId"].groupby(rat["movieId"]).count().sort_values(ascending=False)[rat["userId"].groupby(rat["movieId"]).count().sort_values(ascending=False)>50][:5].index
# Out:
# Int64Index([356, 318, 296, 593, 2571], dtype='int64', name='movieId')

# %%
df1[df1["tag"]=="scifi"]
# Out:
#      userId  movieId    tag   timestamp
# 277      62   108190  scifi  1525554839

# %%
genber = ['Sci-Fi',
 'Sci-fi',
 'Scifi masterpiece',
'sci-fi',
 'science fiction',
 'scifi',
 'scifi cult']

# %%
df1[df1["tag"].isin(genber)]["movieId"].index
# Out:
# Int64Index([  31,  121,  277,  406,  451,  452,  521,  552,  717,  732,  736,
#              765,  777,  816,  853,  854,  932,  961, 2508, 2545, 2579, 2580,
#             2699, 2710, 2725, 2751, 3334, 3578],
#            dtype='int64')

# %%
asd = pd.DataFrame(rat["userId"].groupby(rat["movieId"]).count().sort_values(ascending=False)[rat["userId"].groupby(rat["movieId"]).count().sort_values(ascending=False)>50])

# %%
asd = asd.reset_index()

# %%
asd[asd["movieId"].isin(df1[df1["tag"].isin(genber)]["movieId"].index)]
# Out:
#      movieId  userId
# 35      3578     170
# 81       736     123
# 298     2710      64
# 319      552      61
# 415     2699      53
